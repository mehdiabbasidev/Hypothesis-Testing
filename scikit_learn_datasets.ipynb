# %% [markdown]
# <a href="https://colab.research.google.com/github/mehdiabbasidev/Hypothesis-Testing/blob/main/scikit_learn_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.datasets import fetch_california_housing
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
import sklearn
help(sklearn)

import sklearn.datasets
help(sklearn.datasets)

from sklearn.datasets import load_iris
help(sklearn.datasets.load_iris)
dir(sklearn.datasets.load_iris)

# %%
# import data from dataset by loader
iris = load_iris()
X = iris.data
y = iris.target
iris.feature_names
iris.target_names
# print(iris.DESCR)
X[:,0:3]
X[:5,:]
print(X.shape, y.shape)
plt.plot(X, y, "r.")
# iris.data.shape
# plt.scatter(x=X[:,0],y= y, c=y, cmap=plt.cm.Set1,edgecolors='r')
# plt.scatter(x=X[:,1],y= y, c=y, cmap=plt.cm.Set1,edgecolors='g')
# plt.scatter(x=X[:,2],y= y, c=y, cmap=plt.cm.Set1,edgecolors='b')
# plt.scatter(x=X[:,3],y= y, c=y, cmap=plt.cm.Set1,edgecolors='y')
# Out:
# (150, 4) (150,)
# ...

# %%
# import data from dataset by Fetchers
california_housing=fetch_california_housing()
X=california_housing.data
y=california_housing.target
plt.plot(X, y, "g.")
plt.plot(X[:20,:1], y[:20], "g.")

# %%
#Generate dataset for regression
X, y = make_regression(n_samples=50, n_features=3, random_state=42, noise=2.0, bias=20,shuffle =False)
# plt.plot(X, y, "b.")
plt.scatter(x=X[:, 0],y= y, c=y, cmap=plt.cm.Set1,edgecolors='b')
